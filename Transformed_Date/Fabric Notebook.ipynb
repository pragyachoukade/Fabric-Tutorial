# %% [markdown]
# %%html
# # **Data Engineering Session 1**

# %%
df = spark.read.format("csv").option("header","true").load("Files/RawDataADLS/Returns.csv")
# df now is a Spark DataFrame containing CSV data from "Files/RawDataADLS/Returns.csv".
display(df)
# Out:
# StatementMeta(, 101a99e6-ab82-4242-8646-4638ceb4caf0, 6, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 97d1ae0b-071a-4ddc-a37d-9b66cd71180a)

# %%
df = spark.sql("SELECT * FROM pragyaLakehouse.adlstable LIMIT 1000")
display(df)
# Out:
# StatementMeta(, 101a99e6-ab82-4242-8646-4638ceb4caf0, 7, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 52a6e0a9-d73f-4e06-93b6-43d70cfc3531)
